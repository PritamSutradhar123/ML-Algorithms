# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\salaries.csv")
df
# Out:
#        company                  job     degree  salary_more_then_100k
# 0       google      sales executive  bachelors                      0
# 1       google      sales executive    masters                      0
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 4       google  computer programmer  bachelors                      0
# 5       google  computer programmer    masters                      1
# 6   abc pharma      sales executive    masters                      0
# 7   abc pharma  computer programmer  bachelors                      0
# 8   abc pharma     business manager  bachelors                      0
# 9   abc pharma     business manager    masters                      1
# 10    facebook      sales executive  bachelors                      1
# 11    facebook      sales executive    masters                      1
# ...

# %%
inputs=df.drop('salary_more_then_100k',axis='columns')
target=df['salary_more_then_100k']

# %%
target
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: salary_more_then_100k, dtype: int64

# %%
inputs
# Out:
#        company                  job     degree
# 0       google      sales executive  bachelors
# 1       google      sales executive    masters
# 2       google     business manager  bachelors
# 3       google     business manager    masters
# 4       google  computer programmer  bachelors
# 5       google  computer programmer    masters
# 6   abc pharma      sales executive    masters
# 7   abc pharma  computer programmer  bachelors
# 8   abc pharma     business manager  bachelors
# 9   abc pharma     business manager    masters
# 10    facebook      sales executive  bachelors
# 11    facebook      sales executive    masters
# 12    facebook     business manager  bachelors
# 13    facebook     business manager    masters
# 14    facebook  computer programmer  bachelors
# 15    facebook  computer programmer    masters

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_company=LabelEncoder()
le_job=LabelEncoder()
le_degree=LabelEncoder()

# %%
inputs['company_n']=le_company.fit_transform(inputs['company'])
inputs['job_n']=le_company.fit_transform(inputs['job'])
inputs['degree_n']=le_company.fit_transform(inputs['degree'])

# %%
inputs.head()
# Out:
#   company                  job     degree  company_n  job_n  degree_n
# 0  google      sales executive  bachelors          2      2         0
# 1  google      sales executive    masters          2      2         1
# 2  google     business manager  bachelors          2      0         0
# 3  google     business manager    masters          2      0         1
# 4  google  computer programmer  bachelors          2      1         0

# %%
inputs_n=inputs.drop(['company','job','degree'],axis='columns')

# %%
inputs_n
# Out:
#     company_n  job_n  degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1

# %%
from sklearn import tree

# %%
model=tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)# since its the same dataset
# Out:
# 1.0

# %%
model.predict([[2,2,1]]) #google
# Out:
# C:\Users\suaru\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
f=pd.read_csv("D:/titanic (1).csv")
f
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_f=f.drop(['PassengerId','Fare','Name','Ticket','Cabin','Age'],axis='columns')

# %%
new_f
# Out:
#      Survived  Pclass     Sex  SibSp  Parch Embarked
# 0           0       3    male      1      0        S
# 1           1       1  female      1      0        C
# 2           1       3  female      0      0        S
# 3           1       1  female      1      0        S
# 4           0       3    male      0      0        S
# ..        ...     ...     ...    ...    ...      ...
# 886         0       2    male      0      0        S
# 887         1       1  female      0      0        S
# 888         0       3  female      1      2        S
# 889         1       1    male      0      0        C
# 890         0       3    male      0      0        Q
#
# [891 rows x 6 columns]

# %%
le_Sex=LabelEncoder()
le_Embarked=LabelEncoder()

# %%
new_f['Gender']=le_Sex.fit_transform(new_f['Sex'])
new_f['EMB']=le_Sex.fit_transform(new_f['Embarked'])

# %%
new_f=new_f.drop(['Sex','Embarked'],axis='columns')

# %%
new_f
# Out:
#      Survived  Pclass  SibSp  Parch  Gender  EMB
# 0           0       3      1      0       1    2
# 1           1       1      1      0       0    0
# 2           1       3      0      0       0    2
# 3           1       1      1      0       0    2
# 4           0       3      0      0       1    2
# ..        ...     ...    ...    ...     ...  ...
# 886         0       2      0      0       1    2
# 887         1       1      0      0       0    2
# 888         0       3      1      2       0    2
# 889         1       1      0      0       1    0
# 890         0       3      0      0       1    1
#
# [891 rows x 6 columns]

# %%
inputs1=new_f.drop(['Survived'],axis='columns')
targets1=new_f['Survived']

# %%
model1=tree.DecisionTreeClassifier()
model1.fit(inputs1,targets1)
# Out:
# DecisionTreeClassifier()

# %%
model1.predict([[3,1,0,1,2]])
# Out:
# C:\Users\suaru\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
